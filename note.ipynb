# %%
## blah
import csv
c = open("asana.csv")
for row in c:
    print("\"", row.rstrip(), "\"")
# Out:
# " Asana,English,Sanskrit,Type,Sequence,Variation "
# " Shavasana,Corpse,शवासन,Supine,10,"Butterfly legs, buttterfly legs and arms, reverse corpse (lying on the front)" "
# " Jathara Parivartanasana,Belly twist,ञटर परिवर्तनासन​,Supine,10, "
# " "Viparita Karani, Uttanapadasana (variant)","Inverted practice, Legs up the wall",विपरीतकरणि,Supine,10, "
# " Supta Trivikramasana,Trivikrama's pose reclining variant,सुप्त त्रिविक्रमासन,Supine,10, "
# " Supta Padangusthasana,Big toe supine,सुप्त पादाङ्गुष्ठासन,Supine,10, "
# " "Ardha Pavan Muktasana, apanasana",Half Wind Release Pose,,Supine,10, "
# " Tadasana,Mountain,ताडासन,Standing,20,"side bend, back bend" "
# " Utkatasana,"Awkward, Powerful, Chair",उत्कटासन,Standing,20,One leg "
# " Adho Mukha Shvanasana,Downward-Facing Dog,अधोमुखश्वानासन,Warrior,30, "
# " Anjaneyasana,Crescent Moon,अञ्जनेयासन,Warrior,30, "
# " Virabhadrasana I,Warrior I,वीरभद्रासन,Warrior,30, "
# ...

# %% [markdown]
# a = csv.reader("asana.csv", delimiter=",")
# for row in a:
#     print(' -- '.join(row))

# %%
with open('asana.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile)
    for cell in spamreader:
        print(' - '.join(cell))
        print("----")
    
    print("done")
# Out:
# Asana - English - Sanskrit - Type - Sequence - Variation
# ----
# Shavasana - Corpse - शवासन - Supine - 10 - Butterfly legs, buttterfly legs and arms, reverse corpse (lying on the front)
# ----
# Jathara Parivartanasana - Belly twist - ञटर परिवर्तनासन​ - Supine - 10 -
# ----
# Viparita Karani, Uttanapadasana (variant) - Inverted practice, Legs up the wall - विपरीतकरणि - Supine - 10 -
# ----
# Supta Trivikramasana - Trivikrama's pose reclining variant - सुप्त त्रिविक्रमासन - Supine - 10 -
# ----
# Supta Padangusthasana - Big toe supine - सुप्त पादाङ्गुष्ठासन - Supine - 10 -
# ----
# Ardha Pavan Muktasana, apanasana - Half Wind Release Pose -  - Supine - 10 -
# ----
# Tadasana - Mountain - ताडासन - Standing - 20 - side bend, back bend
# ----
# Utkatasana - Awkward, Powerful, Chair - उत्कटासन - Standing - 20 - One leg
# ----
# Adho Mukha Shvanasana - Downward-Facing Dog - अधोमुखश्वानासन - Warrior - 30 -
# ----
# Anjaneyasana - Crescent Moon - अञ्जनेयासन - Warrior - 30 -
# ----
# ...
